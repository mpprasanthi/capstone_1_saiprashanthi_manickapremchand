# %%
pip install ipython-sql
# Out:
# ...
#
# ...

# %%
# %load_ext sql
# %sql mysql+pymysql://root:Manicka1983@localhost/capstone_1

# %%
# %%sql
# select * from products
# Out:
#  * mysql+pymysql://root:***@localhost/capstone_1
# 8 rows affected.
# [(9, 'PROD_006', 'ZT2000 Zero Turn Mower', 'https://www.bobcat.com/mowers/zero-turn-mowers/zt2000', 'Bobcat', 4575, 4575, 4575, 4575, 4649, 4649, 4649, 4649),
#  (10, 'PROD_005', 'UV34 Gas ', 'https://www.bobcat.com/utility-products/utv/UV34/UV34-gas-utv', 'Bobcat', 13995, 13995, 13995, 13995, 14225, 14225, 14225, 14225),
#  (11, 'PROD_004', 'CT1021 Sub-Compact Tractor', 'https://www.bobcat.com/tractors/models/ct1021/features', 'Bobcat', 11385, 11385, 11385, 11385, 11527, 11527, 11527, 11527),
#  (12, 'PROD_007', 'S70 Skid Steer Loader', 'https://www.bobcat.com/loaders/skid-steer-loaders/models/s70/features', 'Bobcat', 22987, 22987, 22987, 22987, 23120, 23120, 23120, 23120),
#  (13, 'PROD_002', 'CUV82', 'https://www.cat.com/en_US/products/new/equipment/utility-vehicles/utility-vehicles/1000034280.html', 'Cat', 14786, 14786, 14786, 14786, 14998, 14998, 14998, 14998),
# ...

# %%
# %%sql
# select * from esp
# Out:
#  * mysql+pymysql://root:***@localhost/capstone_1
# 8 rows affected.
# [(10, 'ESP_006', 372, 9),
#  (11, 'ESP_005', 843, 10),
#  (12, 'ESP_004', 843, 11),
#  (13, 'ESP_007', 1027, 12),
#  (14, 'ESP_002', 843, 13),
#  (15, 'ESP_001', 843, 14),
#  (16, 'ESP_008', 843, 15),
#  (17, 'ESP_003', 978, 16)]

# %%
# %%sql
# select prod_code, prod_name,esp_code, warranty_price from products p join esp e on p.id = e.prod_id
# Out:
#  * mysql+pymysql://root:***@localhost/capstone_1
# 8 rows affected.
# [('PROD_006', 'ZT2000 Zero Turn Mower', 'ESP_006', 372),
#  ('PROD_005', 'UV34 Gas ', 'ESP_005', 843),
#  ('PROD_004', 'CT1021 Sub-Compact Tractor', 'ESP_004', 843),
#  ('PROD_007', 'S70 Skid Steer Loader', 'ESP_007', 1027),
#  ('PROD_002', 'CUV82', 'ESP_002', 843),
#  ('PROD_001', 'Gator XUV 590M', 'ESP_001', 843),
#  ('PROD_008', 'Z930M Ztrack', 'ESP_008', 843),
#  ('PROD_003', '1025R Sub-Compact Tractor', 'ESP_003', 978)]

# %%
# %%sql
# select * from sales limit 10
# Out:
#  * mysql+pymysql://root:***@localhost/capstone_1
# 10 rows affected.
# [(8324, 'PROD_001', 1, 53, 42, datetime.date(2022, 3, 6)),
#  (8325, 'PROD_001', 1, 54, 48, datetime.date(2022, 3, 6)),
#  (8326, 'PROD_001', 1, 55, 38, datetime.date(2022, 3, 6)),
#  (8327, 'PROD_001', 1, 56, 43, datetime.date(2022, 3, 6)),
#  (8328, 'PROD_001', 1, 57, 35, datetime.date(2022, 3, 6)),
#  (8329, 'PROD_001', 1, 58, 39, datetime.date(2022, 3, 6)),
#  (8330, 'PROD_001', 1, 59, 36, datetime.date(2022, 3, 6)),
#  (8331, 'PROD_001', 1, 60, 38, datetime.date(2022, 3, 6)),
#  (8332, 'PROD_001', 1, 61, 49, datetime.date(2022, 3, 6)),
#  (8333, 'PROD_001', 1, 62, 46, datetime.date(2022, 3, 6))]

# %%
# %%sql
# select * from sales_team
# Out:
#  * mysql+pymysql://root:***@localhost/capstone_1
# 5 rows affected.
# [(1, 'Evans, Gina', 'C12', 'NW', 'EMP244', 1),
#  (2, 'Lawson, Harry', 'C11', 'NW', 'EMP256', 1),
#  (3, 'Bachmann, Jane', 'C13', 'NW', 'EMP234', 1),
#  (4, 'Clement, Beverly', 'C14', 'SW', 'EMP267', 1),
#  (5, 'Allen, Maude', 'C12', 'SW', 'EMP290', 1)]

# %%
# %%sql
# SELECT sales.emp_id,sales_team_lead,pay_grade,region,sold_count,sale_date FROM sales JOIN sales_team
# on sales.emp_id = sales_team.id
# group by pay_grade;
# Out:
#  * mysql+pymysql://root:***@localhost/capstone_1
# 4 rows affected.
# [(1, 'Evans, Gina', 'C12', 'NW', 42, datetime.date(2022, 3, 6)),
#  (2, 'Lawson, Harry', 'C11', 'NW', 26, datetime.date(2022, 3, 6)),
#  (3, 'Bachmann, Jane', 'C13', 'NW', 31, datetime.date(2022, 3, 6)),
#  (4, 'Clement, Beverly', 'C14', 'SW', 32, datetime.date(2022, 3, 6))]
